# %%
import h5py
import numpy as np
import scipy.signal as signal
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
font1={'family':'Times New Roman',
       'weight': 'normal',
       'size':30,
}
dir = 'E:\PaperSupport\SVG'

# %%
plt.figure(figsize=(20,8))
for j in range(1, 2):
    dfraw = pd.read_hdf('F:/DB2/raw/DB2_s' + str(j) + 'raw.h5', 'df')
    dfraw = np.array(dfraw)
    label = dfraw[:, 12]
    dfraw = dfraw[430000:540000,]
    for i in range(len(dfraw) ):
        if (dfraw[i, 12] != 0):
            dfraw[i, 13] = 600
  
    plt.plot(dfraw[:, 0:12], linestyle='-')
    plt.plot(dfraw[:, 13],color='c', linestyle='--',label='stimulus')
 
    plt.xlabel('Samples', font1)
    plt.ylabel('sEMG signal', font1)
    plt.legend(prop=font1, loc=1)
